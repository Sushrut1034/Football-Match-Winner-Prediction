# %%
import pandas as pd

# %%
matches = pd.read_csv("matches4.csv" , index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1     1
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0     0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0     0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0     0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0     0
#
#    season             team
# 1    2023  Manchester City
# 2    2023  Manchester City
# 3    2023  Manchester City
# 4    2023  Manchester City
# 5    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (2280, 27)

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] =matches["venue"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  notes    sh   sot  dist   fk pk pkatt season  \
# 1         West Ham  ...    NaN  13.0   1.0  18.7  1.0  1     1   2023
# 2      Bournemouth  ...    NaN  19.0   7.0  17.5  0.0  0     0   2023
# 3    Newcastle Utd  ...    NaN  21.0  10.0  16.2  1.0  0     0   2023
# 4   Crystal Palace  ...    NaN  18.0   5.0  14.1  0.0  0     0   2023
# 5  Nott'ham Forest  ...    NaN  17.0   9.0  14.8  0.0  0     0   2023
#
#               team  venue_code
# 1  Manchester City           0
# 2  Manchester City           1
# 3  Manchester City           0
# 4  Manchester City           1
# 5  Manchester City           1
#
# [5 rows x 28 columns]

# %%
matches["opp_code"] =matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+" , "",regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  dist   fk  pk  pkatt season             team  \
# 1         West Ham  ...  18.7  1.0   1      1   2023  Manchester City
# 2      Bournemouth  ...  17.5  0.0   0      0   2023  Manchester City
# 3    Newcastle Utd  ...  16.2  1.0   0      0   2023  Manchester City
# 4   Crystal Palace  ...  14.1  0.0   0      0   2023  Manchester City
# 5  Nott'ham Forest  ...  14.8  0.0   0      0   2023  Manchester City
#
#   venue_code opp_code  hour  day_code
# 1          0       23    16         6
# 2          1        2    15         5
# 3          0       15    16         6
# 4          1        7    15         5
# 5          1       17    19         2
#
# [5 rows x 31 columns]

# %%
matches["target"] = (matches["result"]=="W").astype("int")

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...   fk  pk  pkatt  season             team venue_code  \
# 1         West Ham  ...  1.0   1      1    2023  Manchester City          0
# 2      Bournemouth  ...  0.0   0      0    2023  Manchester City          1
# 3    Newcastle Utd  ...  1.0   0      0    2023  Manchester City          0
# 4   Crystal Palace  ...  0.0   0      0    2023  Manchester City          1
# 5  Nott'ham Forest  ...  0.0   0      0    2023  Manchester City          1
#
#   opp_code hour  day_code  target
# 1       23   16         6       1
# 2        2   15         5       1
# 3       15   16         6       0
# 4        7   15         5       1
# 5       17   19         2       1
#
# [5 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, min_samples_split=55, random_state=1)

# %%
train = matches[matches["date"] < '2023-06-01']

# %%
test = matches[matches["date"] > '2022-06-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=55, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.6789473684210526

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          429  38
# 1          206  87

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.696

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D   1   1
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L   0   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
#          opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 5         Arsenal  ...         5       1    2.000000    2.333333  17.333333
# 7        West Ham  ...         5       0    1.333333    2.000000  17.333333
# 9   Sheffield Utd  ...         5       1    1.000000    0.666667  16.666667
# 11      Liverpool  ...         6       0    1.000000    0.333333  14.333333
# 12      Tottenham  ...         5       0    1.000000    0.666667  12.000000
# ..            ...  ...       ...     ...         ...         ...        ...
# 52   Leeds United  ...         5       1    3.000000    0.666667  13.666667
# 54        Everton  ...         6       1    2.333333    0.666667  14.666667
# 56        Chelsea  ...         6       1    2.666667    0.333333  14.000000
# 57       Brighton  ...         2       0    2.000000    0.333333  13.666667
# 58      Brentford  ...         6       0    1.666667    0.333333  12.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 5     4.666667    19.700000   1.333333    0.333333       0.333333
# 7     3.666667    18.566667   0.666667    0.000000       0.000000
# 9     4.333333    18.933333   0.666667    0.000000       0.000000
# 11    6.666667    19.033333   1.000000    0.000000       0.000000
# 12    5.666667    20.000000   1.000000    0.000000       0.333333
# ..         ...          ...        ...         ...            ...
# 52    8.000000    15.433333   0.000000    0.333333       0.333333
# 54    7.000000    16.366667   0.666667    0.333333       0.666667
# 56    5.666667    18.100000   1.333333    0.000000       0.333333
# 57    4.000000    18.933333   1.333333    0.000000       0.333333
# 58    3.333333    17.333333   0.666667    0.000000       0.000000
#
# [111 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 39 2023-04-29  15:00  Premier League  Matchweek 34
#                         40 2023-05-06  15:00  Premier League  Matchweek 35
#                         41 2023-05-13  15:00  Premier League  Matchweek 36
#                         42 2023-05-20  15:00  Premier League  Matchweek 37
#                         43 2023-05-28  16:30  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 6   Sun  Home      W   2   1    Sheffield Utd  ...
#                         7   Sat  Away      L   0   1  Manchester City  ...
#                         9   Sun  Home      L   0   1   Leicester City  ...
#                         11  Sun  Away      W   1   0   Manchester Utd  ...
#                         13  Sun  Home      L   0   3      Aston Villa  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 39  Sat  Away      L   0   6         Brighton  ...
#                         40  Sat  Home      W   1   0      Aston Villa  ...
#                         41  Sat  Away      L   0   2   Manchester Utd  ...
#                         42  Sat  Home      D   1   1          Everton  ...
#                         43  Sun  Away      L   0   5          Arsenal  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 6          6       1    2.000000    1.333333
#                         7          5       0    1.666667    1.666667
#                         9          6       0    1.000000    1.666667
#                         11         6       1    0.666667    1.000000
#                         13         6       0    0.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 39         5       0    1.666667    0.666667
#                         40         5       1    1.000000    2.666667
#                         41         5       0    1.000000    2.000000
#                         42         5       0    0.333333    2.666667
#                         43         6       0    0.666667    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 6    8.000000    3.666667    14.633333   0.666667
#                         7    5.666667    3.666667    15.366667   0.000000
#                         9    7.000000    3.666667    16.566667   0.666667
#                         11   9.666667    4.000000    16.566667   1.000000
#                         13   9.666667    2.666667    19.333333   1.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 39  11.666667    4.666667    18.700000   0.666667
#                         40  11.333333    2.333333    18.800000   0.666667
#                         41   8.000000    2.000000    17.766667   0.000000
#                         42   7.000000    1.333333    15.600000   0.000000
#                         43   8.000000    2.333333    15.333333   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 6     0.000000       0.000000
#                         7     0.000000       0.000000
#                         9     0.000000       0.000000
#                         11    0.000000       0.000000
#                         13    0.333333       0.333333
# ...                                ...            ...
# Wolverhampton Wanderers 39    0.333333       0.333333
#                         40    0.333333       0.333333
#                         41    0.333333       0.333333
#                         42    0.000000       0.000000
#                         43    0.000000       0.000000
#
# [2202 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2   1
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0   1
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0   1
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1   0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 39 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0   6
# 40 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1   0
# 41 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0   2
# 42 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1   1
# 43 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   5
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 6     Sheffield Utd  ...         6       1    2.000000    1.333333   8.000000
# 7   Manchester City  ...         5       0    1.666667    1.666667   5.666667
# 9    Leicester City  ...         6       0    1.000000    1.666667   7.000000
# 11   Manchester Utd  ...         6       1    0.666667    1.000000   9.666667
# 13      Aston Villa  ...         6       0    0.333333    0.666667   9.666667
# ..              ...  ...       ...     ...         ...         ...        ...
# 39         Brighton  ...         5       0    1.666667    0.666667  11.666667
# 40      Aston Villa  ...         5       1    1.000000    2.666667  11.333333
# 41   Manchester Utd  ...         5       0    1.000000    2.000000   8.000000
# 42          Everton  ...         5       0    0.333333    2.666667   7.000000
# 43          Arsenal  ...         6       0    0.666667    1.000000   8.000000
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 6     3.666667    14.633333   0.666667    0.000000       0.000000
# 7     3.666667    15.366667   0.000000    0.000000       0.000000
# 9     3.666667    16.566667   0.666667    0.000000       0.000000
# 11    4.000000    16.566667   1.000000    0.000000       0.000000
# 13    2.666667    19.333333   1.000000    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 39    4.666667    18.700000   0.666667    0.333333       0.333333
# 40    2.333333    18.800000   0.666667    0.333333       0.333333
# 41    2.000000    17.766667   0.000000    0.333333       0.333333
# 42    1.333333    15.600000   0.000000    0.000000       0.000000
# 43    2.333333    15.333333   0.333333    0.000000       0.000000
#
# [2202 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.73568281938326

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 55       0          1 2022-01-23  Arsenal         Burnley      D
# 56       1          1 2022-02-10  Arsenal          Wolves      W
# 57       1          0 2022-02-19  Arsenal       Brentford      W
# 58       1          1 2022-02-24  Arsenal          Wolves      W
# 59       1          1 2022-03-06  Arsenal         Watford      W
# 60       1          1 2022-03-13  Arsenal  Leicester City      W
# 61       0          0 2022-03-16  Arsenal       Liverpool      L
# 62       1          0 2022-03-19  Arsenal     Aston Villa      W
# 63       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 64       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       date                   team_x  \
# 0            0            1 2022-01-23                  Arsenal
# 1            1            1 2022-02-10                  Arsenal
# 2            1            0 2022-02-19                  Arsenal
# 3            1            1 2022-02-24                  Arsenal
# 4            1            1 2022-03-06                  Arsenal
# ...        ...          ...        ...                      ...
# 1096         0            0 2023-04-29  Wolverhampton Wanderers
# 1097         1            0 2023-05-06  Wolverhampton Wanderers
# 1098         0            0 2023-05-13  Wolverhampton Wanderers
# 1099         0            0 2023-05-20  Wolverhampton Wanderers
# 1100         0            0 2023-05-28  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0            Burnley        D    Arsenal         0            0
# 1             Wolves        W    Arsenal         0            0
# 2          Brentford        W    Arsenal         0            0
# 3             Wolves        W    Arsenal         0            0
# 4            Watford        W    Arsenal         0            0
# ...              ...      ...        ...       ...          ...
# 1096        Brighton        L     Wolves         1            1
# 1097     Aston Villa        W     Wolves         0            0
# 1098  Manchester Utd        L     Wolves         1            1
# 1099         Everton        D     Wolves         0            0
# 1100         Arsenal        L     Wolves         1            0
#
#                         team_y opponent_y result_y      new_team_y
# 0                      Burnley    Arsenal        D         Burnley
# 1      Wolverhampton Wanderers    Arsenal        L          Wolves
# 2                    Brentford    Arsenal        L       Brentford
# 3      Wolverhampton Wanderers    Arsenal        L          Wolves
# 4                      Watford    Arsenal        L         Watford
# ...                        ...        ...      ...             ...
# 1096  Brighton and Hove Albion     Wolves        W        Brighton
# 1097               Aston Villa     Wolves        L     Aston Villa
# 1098         Manchester United     Wolves        W  Manchester Utd
# 1099                   Everton     Wolves        D         Everton
# 1100                   Arsenal     Wolves        W         Arsenal
#
# [1101 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    160
# 0     53
# Name: count, dtype: int64

# %%
160/213
# Out:
# 0.7511737089201878
